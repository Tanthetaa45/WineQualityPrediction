# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import sys

# %%
Path = "/Volumes/Extreme SSD/WineQualityPrediction/data/raw"


df = pd.read_csv(os.path.join(Path, "winequality-white.csv"), sep=';')
df1 = pd.read_csv(os.path.join(Path, "winequality-red.csv"), sep=';')
df['type'] = 'white'  
df1['type'] = 'red'   
print(df.info())
print(df1.info())


print(df.head())
print(df1.head())


print(df.isnull().sum())
print(df1.isnull().sum())
print(df.describe())
print(df1.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
#  12  type                  4898 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 497.6+ KB
# None
# ...

# %%
wine_df = pd.concat([df, df1], ignore_index=True)
print(wine_df.info())
print(wine_df['type'].value_counts())
print(wine_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  type                  6497 non-null   object
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB
# None
# type
# white    4898
# ...

# %%
print(wine_df.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
import pandas as pd
column_info = {
    'fixed acidity': ('g(tartaric acid)/dm³', 'Tartaric acid (main acid in grapes)'),
    'volatile acidity': ('g(acetic acid)/dm³', 'Acetic acid (vinegar-like)'),
    'citric acid': ('g/dm³', 'Citric acid (adds freshness)'),
    'residual sugar': ('g/dm³', 'Unfermented sugar (affects sweetness)'),
    'chlorides': ('g(sodium chloride)/dm³', 'Salt content'),
    'free sulfur dioxide': ('mg/dm³', 'Free SO₂ (active preservative)'),
    'total sulfur dioxide': ('mg/dm³', 'Total SO₂ (free + bound)'),
    'density': ('g/cm³', 'Density of the wine'),
    'pH': ('–', 'Acidity/basicity level'),
    'sulphates': ('g(potassium sulphate)/dm³', 'Sulphates (antimicrobial agent)'),
    'alcohol': ('% vol', 'Alcohol concentration'),
    'quality': ('score (0–10)', 'Median of sensory taste ratings by experts')
}


print("Wine Dataset Columns with Units and Meanings:\n")
for col in df.columns:
    unit, meaning = column_info.get(col, ('', ''))
    print(f"{col:<25} | Unit: {unit:<20} | Meaning: {meaning}")
# Out:
# Wine Dataset Columns with Units and Meanings:
#
# fixed acidity             | Unit: g(tartaric acid)/dm³ | Meaning: Tartaric acid (main acid in grapes)
# volatile acidity          | Unit: g(acetic acid)/dm³   | Meaning: Acetic acid (vinegar-like)
# citric acid               | Unit: g/dm³                | Meaning: Citric acid (adds freshness)
# residual sugar            | Unit: g/dm³                | Meaning: Unfermented sugar (affects sweetness)
# chlorides                 | Unit: g(sodium chloride)/dm³ | Meaning: Salt content
# free sulfur dioxide       | Unit: mg/dm³               | Meaning: Free SO₂ (active preservative)
# total sulfur dioxide      | Unit: mg/dm³               | Meaning: Total SO₂ (free + bound)
# density                   | Unit: g/cm³                | Meaning: Density of the wine
# pH                        | Unit: –                    | Meaning: Acidity/basicity level
# ...
